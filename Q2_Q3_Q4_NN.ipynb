# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

(train_images, train_labels), (test_images, test_labels) = datasets.mnist.load_data()

train_images, test_images = train_images / 255.0, test_images / 255.0

train_images = train_images.reshape((train_images.shape[0], 28, 28, 1))
test_images = test_images.reshape((test_images.shape[0], 28, 28, 1))
model = models.Sequential()
model.add(layers.Flatten())
model.add(layers.Input(784))
model.add(layers.Dense(5, activation='sigmoid'))
model.add(layers.Dense(10, activation='softmax'))

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_images, train_labels, epochs=5, 
                    validation_data=(test_images, test_labels))

test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc}")


plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.show()
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 1.4352 - accuracy: 0.5878 - val_loss: 1.0425 - val_accuracy: 0.6956
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.9034 - accuracy: 0.7538 - val_loss: 0.7767 - val_accuracy: 0.8099
# Epoch 3/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.6979 - accuracy: 0.8271 - val_loss: 0.6139 - val_accuracy: 0.8496
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.5805 - accuracy: 0.8514 - val_loss: 0.5280 - val_accuracy: 0.8633
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.5171 - accuracy: 0.8619 - val_loss: 0.4763 - val_accuracy: 0.8725
# 313/313 [==============================] - 0s 1ms/step - loss: 0.4763 - accuracy: 0.8725
# Test accuracy: 0.8725000023841858

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt


# Load the MNIST dataset
(train_images, train_labels), (test_images, test_labels) = datasets.mnist.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# Reshape the data to include the channel dimension
train_images = train_images.reshape((train_images.shape[0], 28, 28, 1))
test_images = test_images.reshape((test_images.shape[0], 28, 28, 1))
model = models.Sequential()
model.add(layers.Flatten())
model.add(layers.Dense(784, activation='sigmoid'))
model.add(layers.Dense(512, activation='sigmoid'))
model.add(layers.Dense(256, activation='sigmoid'))
model.add(layers.Dense(10, activation='softmax'))

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_images, train_labels, epochs=5, 
                    validation_data=(test_images, test_labels))

test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc}")


plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.show()
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3420 - accuracy: 0.8946 - val_loss: 0.1848 - val_accuracy: 0.9449
# Epoch 2/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1343 - accuracy: 0.9592 - val_loss: 0.1318 - val_accuracy: 0.9599
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0891 - accuracy: 0.9726 - val_loss: 0.0904 - val_accuracy: 0.9728
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0636 - accuracy: 0.9800 - val_loss: 0.0750 - val_accuracy: 0.9774
# Epoch 5/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0481 - accuracy: 0.9845 - val_loss: 0.0835 - val_accuracy: 0.9770
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0835 - accuracy: 0.9770
# Test accuracy: 0.9769999980926514

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt


(train_images, train_labels), (test_images, test_labels) = datasets.mnist.load_data()

train_images, test_images = train_images / 255.0, test_images / 255.0

train_images = train_images.reshape((train_images.shape[0], 28, 28, 1))
test_images = test_images.reshape((test_images.shape[0], 28, 28, 1))
model = models.Sequential()
model.add(layers.Conv2D(20, (9,9), activation='relu'))
model.add(layers.AveragePooling2D(pool_size=(2,2)))
model.add(layers.Flatten())

model.add(layers.Dense(100, activation="relu"))
model.add(layers.Dense(10, activation='softmax'))

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_images, train_labels, epochs=5, 
                    validation_data=(test_images, test_labels))

test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc}")


plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.show()
# Out:
# Epoch 1/5
# 2024-07-28 15:38:12.676339: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8600
# 2024-07-28 15:38:12.873524: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-07-28 15:38:13.105928: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-07-28 15:38:13.192673: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x78c139493440 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-07-28 15:38:13.192716: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4070 Laptop GPU, Compute Capability 8.9
# 2024-07-28 15:38:13.201401: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-07-28 15:38:13.278699: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1629 - accuracy: 0.9512 - val_loss: 0.0532 - val_accuracy: 0.9829
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0569 - accuracy: 0.9825 - val_loss: 0.0502 - val_accuracy: 0.9833
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0390 - accuracy: 0.9881 - val_loss: 0.0385 - val_accuracy: 0.9865
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0289 - accuracy: 0.9908 - val_loss: 0.0356 - val_accuracy: 0.9879
# Epoch 5/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0220 - accuracy: 0.9924 - val_loss: 0.0375 - val_accuracy: 0.9875
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0375 - accuracy: 0.9875
# Test accuracy: 0.987500011920929

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt


(train_images, train_labels), (test_images, test_labels) = datasets.mnist.load_data()

train_images, test_images = train_images / 255.0, test_images / 255.0

train_images = train_images.reshape((train_images.shape[0], 28, 28, 1))
test_images = test_images.reshape((test_images.shape[0], 28, 28, 1))
model = models.Sequential()
model.add(layers.Conv2D(20, (9,9), activation='relu'))
model.add(layers.Conv2D(12, (9,9), activation='relu'))
model.add(layers.Conv2D(8, (9,9), activation='relu'))
model.add(layers.AveragePooling2D(pool_size=(2,2)))
model.add(layers.Flatten())

model.add(layers.Dense(128, activation="relu"))
model.add(layers.Dense(64, activation="relu"))
model.add(layers.Dense(32, activation="relu"))
model.add(layers.Dense(10, activation='softmax'))

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_images, train_labels, epochs=5, 
                    validation_data=(test_images, test_labels))

test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc}")


plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.show()
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2776 - accuracy: 0.9132 - val_loss: 0.1072 - val_accuracy: 0.9674
# Epoch 2/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0946 - accuracy: 0.9714 - val_loss: 0.0738 - val_accuracy: 0.9768
# Epoch 3/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0732 - accuracy: 0.9780 - val_loss: 0.0696 - val_accuracy: 0.9795
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0629 - accuracy: 0.9811 - val_loss: 0.0577 - val_accuracy: 0.9816
# Epoch 5/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0563 - accuracy: 0.9835 - val_loss: 0.0431 - val_accuracy: 0.9862
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0431 - accuracy: 0.9862
# Test accuracy: 0.9861999750137329
